# %% [markdown]
# # <font color='navy'> <i><b> STEMFIE-X Component connection - Couplers </i></b> </font>
# <img src="./img/banner_02.png" width="800">
#
# ## <font color='purple'> <b> Couplers components </b></font>
#
#  <table>
#   <tr>
#     <th>  <img src="./img/spojka_01.png" width="400"></th>
#     <th>  <img src="./img/spojka_02.png" width="400"> </th>
#   </tr>
#   <tr>
#     <th>  <img src="./img/spojka_03.png" width="400"> </th>
#     <th>  <img src="./img/spojka_04.jpg" width="400"> </th>
#   </tr>
# </table>

# %%
from lib import *

cc1 = Beam_Block([3/4, 3/4, 4], [True, True, False])   
cc1.export_step('./step/coupler/coupler_B_34_34_04')
cc1.Ry(45).Rz(45)
display(SVG(cc1.obj.toSvg()))

# %%
cc3 = Beam_Block([3/4, 3/4, 2], [True, True, False])   
cc3.export_step('./step/coupler/coupler_B_34_34_02')
cc3.Ry(45).Rz(45)
display(SVG(cc3.obj.toSvg()))

# %%
cc4 = Beam_Block([3/4, 3/4, 1], [True, True, False])   
cc4.export_step('./step/coupler/coupler_B_34_34_01')
cc4.Ry(45).Rz(45)
display(SVG(cc4.obj.toSvg()))

# %%
cc2 = Beam_Block([3/4, 1, 4], [True, True, False]) 
cc2.export_step('./step/coupler/coupler_B_34_10_04')
cc2.Ry(45).Rz(45)
display(SVG(cc2.obj.toSvg()))

# %%
cc5 = Beam_Block([3/4, 1, 2], [True, True, False]) 
cc5.export_step('./step/coupler/coupler_B_34_10_02')
cc5.Ry(45).Rz(45)
display(SVG(cc5.obj.toSvg()))

# %%
b4 = Beam_L_Block(2,2, 1/2, 1/2)#.Rx(45)   # 4x3 BU U-Shape plate 
b4.export_step('./step/coupler/coupler_L_02_01_12_12')
display(SVG(b4.obj.toSvg()))

# %%
b4 = Beam_L_Block(1,2, 1/2, 1/2)#.Rx(45)   # 4x3 BU U-Shape plate 
b4.export_step('./step/coupler/coupler_L_01_01_12_12')
display(SVG(b4.obj.toSvg()))

# %% [markdown]
# <img src="./img/banner_02.png" width="800">
