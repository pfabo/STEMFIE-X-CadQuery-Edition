# %% [markdown]
# # <font color='navy'> <i><b> STEMFIE-X Fences</i></b> </font>
# <img src="./img/banner_02.png" width="800">

# %%
from lib import *
f1 = Fence(8, 2, 2, 1/4)
f1.export_step('./step/fence/fence_02_02_02_14')
display(SVG(f1.obj.toSvg()))

# %%
f2 = Fence(5, 4, 2, 1/4)
f2.export_step('./step/fence/fence_05_04_02_14')
display(SVG(f2.obj.toSvg()))

# %%
f3 = Fence(8, 2, 1, 1/4)
f3.export_step('./step/fence/fence_08_02_01_14')
display(SVG(f3.obj.toSvg()))

# %%
f4 = Fence(5, 4, 1, 1/4)
f4.export_step('./step/fence/fence_05_04_01_14')
display(SVG(f4.obj.toSvg()))

# %% [markdown]
# <img src="./img/banner_02.png" width="800">
