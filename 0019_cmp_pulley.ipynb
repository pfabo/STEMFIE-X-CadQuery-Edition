# %% [markdown]
# # <font color='navy'> <i><b> STEMFIE-X Pulleys and wheels </i></b> </font>
# <img src="./img//demo/banner_02.png" width="800">
#
# General purpose pulleys and wheels set with holders.
#
# <img src="./img/image_pulley.png" width="800">
#
# ## <font color='purple'> <b> Basic library classes </b></font>
#
# **Pulley**
#
#     Pulley(type, holes=True, fill=False, thick=0.8, beams=3)
#
# **Pulley Holder**
#
#     Pulley_Holder_1(height)
#     Pulley_Holder_2(height)
#
# **Simple Wheels**
#
#     Wheel(r, h=1/4, d=1/2 )
#         r - diameter in BU, range [1,2]
#         h - height in BU
#         d - shaft offset
#
# ## <font color='Purple'> <b> Usage - Pulleys and Holders</i> </b> </font>

# %%
from lib import *

N = 2
p1 = Pulley(N)
p1.export_step('./step/pull_02_01')

p2 = Pulley_Holder_1(N)
p2.export_step('./step/comp_PH_01_02')

# assembly pulley and holders
p1 = p1.Rx().BU_T([1/2, -1/2, N])
p3 = p2.copy().Rz(180).BU_Txy([1,-1])
p1.U([p2,p3]).Rx(-90).Ry(30)

Image(convert_to_image(p1,'./img/pulley_01'), width=600)

# %%
N = 3
p1 = Pulley(N)
p1.export_step('./step/pull_03_01')

p2 = Pulley_Holder_1(N)
p2.export_step('./step/comp_PH_01_03')

p1.Rx().BU_T([1/2, -1/2, N])
p3 = p2.copy().Rz(180).BU_Txy([1,-1])
p1.U([p2,p3]).Rx(-90).Ry(30)

Image(convert_to_image(p1,'./img/pulley_02'), width=800)

# %%
N = 3
p1 = Pulley(N).Rx().BU_T([1/2, -1/2, N])
p2 = Pulley_Holder_2(N)
p2.export_step('./step/comp_PH_02_03')

p3 = p2.copy().Rz(180).BU_Txy([1,-1])
p1.U([p2,p3]).Rx(-90).Ry(30)


Image(convert_to_image(p1,'./img/pulley_03'), width=800)

# %% [markdown]
# ## <font color='Purple'> <b> Usage - Wheels</i> </b> </font>

# %%
w1 = Wheel(1)
Image(convert_to_image(w1,'./img/wheel_01'), width=800)

# %%
w2 = Wheel(2, 1/2)
Image(convert_to_image(w2,'./img/wheel_02'), width=800)

# %%
w3 = Wheel(3, 1/2)
Image(convert_to_image(w3,'./img/wheel_03'), width=800)

# %% [markdown]
# <img src="./img//demo/banner_02.png" width="800">
