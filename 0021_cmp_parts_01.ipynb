# %% [markdown]
# # <font color='navy'> <i><b> STEMFIE-X Simple mechanical assemblies</i></b> </font>
# <img src="./img//demo/banner_02.png" width="800">
#
# ## <font color='teal'> <b> Movable pulley mounting in the beam </b></font>

# %%
from lib import *

# Free pulley on braces - for crane arms

p1 = Pulley(1, holes=True, fill=False, thick=0.45 ).Rx()

b1 = Brace(5).Rx().BU_Ty(-1/4)
b2 = b1.copy().Mx()
b3 = Brace(2, 1/2).Rx().BU_Ty(1/4).BU_Tx(2)

# main beam
b4 = Brace(7).Rx().Ry().BU_Tz(3).BU_Ty(-1/2).BU_Tx(4)
b5 = b4.copy().Mx()

# axes
br1 = BU_Bar(2).Rx()
br2 = BU_Bar(2).Rx().BU_Tx(4)

b1.U([p1, b1, b2, b3, b4, b5, br1, br2]).Rx().Ry(135)

Image(convert_to_image(b1,'./img/parts_01'), width=800)

# %% [markdown]
# ## <font color='teal'> <b> Crank Handle </b></font>
#
# Crank handle composed from wheel, cylinder and M4 screew (25mm length).
#
# ```Python
# w1 = Whell(1, 1/2)
# w1.export_step('w1')
#
# c1 = BU_Cylinder(1, 1+1/2)
# c1.export_step('c1')
# ```
#
# <img src='./img/assembly/kluka.png' width="800">
#
# <img src="./img//demo/banner_02.png" width="800">
