# %% [markdown]
# # <font color='navy'> <i><b> Operations</i></b> </font>
#
# Commands in abbreviated format to simplify manipulation of objects.
#
# ## <font color='purple'> <b> Translations </b></font>
#
#     BU_Tx(n)
#     BU_Ty(n)
#     BU_Tz(n)
#     BU_Txy([x,y])
#     BU_T([x,y,z])
#     Tx(d)
#     Ty(d)
#     Tz(d)
#     T([dx,dy,dz])
#
# ## <font color='purple'> <b> Rotations </b></font>
#
#     Rx(angle)
#     Ry(angle)
#     Rz(angle)
#
# ## <font color='purple'> <b> Mirroring and Mirroring with copy </b></font>
#
#     Mx()
#     My()
#     Mz()
#     MKx()
#     MKy()
#     MKz()  [Todo]
#
# ## <font color='purple'> <b> Boolean operations </b></font>
#
#     U(c)        union
#     D(c)        difference
#     I(c)        intersection
#
# ### <font color='teal'> Example </i></b> </font>

# %%
from lib import *

# U-Shape Beam Block
b1 = Beam_Block([3,1,1])
b2 = Beam_Block([3,1,1]).Ry()
b3 = Beam_Block([3,1,1]).Ry().BU_Tx(2)

b1.U([b2,b3]).Rx(30)

convert_to_image(b1,'./img/op1')
Image('./img/op1.png', width=600)
