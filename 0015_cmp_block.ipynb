# %%
from IPython.display import Image
Image(filename='./img/image_block.png', width=800)

# %% [markdown]
# # <font color='navy'> <i><b> Beam_Blocks</i></b> </font>
#
# Basic block components:
#
#     Beam_Block(dim, center)
#     Beam_Arc(diam, angle)          [ToDo]
#
# ### <font color='teal'> Examples </i></b> </font>

# %%
from lib import *

b1 = Beam_Block([3, 2 ,1], [True, True, True]) .BU_Tx(4).BU_Tx(4)
b2 = Beam_Block([3, 4 ,1/2], [False, False, True]).BU_Tx(4)

b1.U(b2).Rx(-45)


convert_to_image(b1,'./img/block_01')
Image('./img/block_01.png', width=800)
