# %%
from IPython.display import Image
Image(filename='./img/image_block.png', width=800)

# %% [markdown]
# # <font color='navy'> <i><b> Beam_Blocks</i></b> </font>
#
# The basic Beam_Block components is used to create beams and plates.
#
#     Beam_Block([x,y,z], center)
#     Beam_Block(d, center)
#
# ### <font color='teal'> Examples </i></b> </font>

# %%
# General Beam_Block

from lib import *

b1 = Beam_Block(5)

convert_to_image(b1,'./img/block_01')
Image('./img/block_01.png', width=400)

# %%
# 2x3 Beam_Block

b2 = Beam_Block([3, 2 ,1], [True, True, True]) .BU_Tx(4).BU_Tx(4)

convert_to_image(b2,'./img/block_02')
Image('./img/block_02.png', width=700)

# %%
# 4x3 BU plate created from Beam_Block

b3 = Beam_Block([4, 3 ,1/2], [False, False, True])

convert_to_image(b3,'./img/block_03')
Image('./img/block_03.png', width=800)
