# %% [markdown]
# # <font color='navy'> <b> Stemfie-X Example - Small Windmill</b></font>
#
# <img src="./img/demo/banner_02.png" width="800">
#
# A simple hand-powered windmill for the youngest constructors.
#
# <img src="./img/0105b_assembly.jpg" width="300">
# <img src="./img/0105a_design.png" width="300">

# %% [markdown]
# ### <font color='purple'> <b> Components </b></font>
#
# All STEP files needed to 3D print and build the model are in the directory **./notebook/model/step_02_windmill/**.

# %%
from lib import *
b14 = Brace(5);                 b14.export_step('./model/step_02_small_windmill/brace_B_05')         # 5 pcs
b15 = Brace(10);                b15.export_step('./model/step_02_small_windmill/brace_B_10')         # 2 pcs
b16 = Beam_U_Block(10,5, 1/4, 1/2);  b16.export_step('./model/step_02_small_windmill/block_U_10_05') # 1 pcs
p01 = Pulley(2,1/2);            p01.export_step('./model/step_02_small_windmill/pull_B_12')          # 2 pcs
w02 = Wheel(1, 1/4, 1/2);       w02.export_step('./model/step_02_small_windmill/wheel_A_14_12')      # 1 pcs
w03 = Wheel(2, 1/2, 1/2);       w03.export_step('./model/step_02_small_windmill/wheel_B_12_12')      # 1 pcs
c02 = BU_Cylinder(1,2);         c02.export_step('./model/step_02_small_windmill/base_C_01_02')       # 1 pcs

# %%
from lib import *
from numpy import arcsin, pi

D = 6   # D >= 2*R+1  
R = 3   # arc radius

alpha = arcsin( (D-1) / (2*R ) )
beta = 2*alpha
H = R*cos(alpha)
bdeg = beta/pi*180     # convert rad -> deg
h = R*cos(alpha)
br1 = Brace_Arc(R, bdeg, 1/4, 5, center=True);  br1.export_step('./model//step_02_small_windmill/brace_A_03_14_06_112')  # 2 pcs
Image(convert_to_image(br1,'./img/brace_A_03_14_06_112'), width=400)

# %% [markdown]
# <img src="./img/0105c_parts.jpg" width="400">
# <img src="./img/demo/banner_02.png" width="800">
